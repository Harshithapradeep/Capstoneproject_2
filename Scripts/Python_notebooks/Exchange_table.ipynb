# %%
# %run ./common.ipynb

# %%
import pandas as pd
Exchange=r"C:\Users\hbhat\OneDrive\Desktop\VScode\Data_Spark_Project\Dataset\Exchange_Rates.csv"
rate_df=pd.read_csv(Exchange)
rate_df
# Out:
#             Date Currency  Exchange
# 0       1/1/2015      USD    1.0000
# 1       1/1/2015      CAD    1.1583
# 2       1/1/2015      AUD    1.2214
# 3       1/1/2015      EUR    0.8237
# 4       1/1/2015      GBP    0.6415
# ...          ...      ...       ...
# 11210  2/20/2021      USD    1.0000
# 11211  2/20/2021      CAD    1.2610
# 11212  2/20/2021      AUD    1.2723
# 11213  2/20/2021      EUR    0.8238
# 11214  2/20/2021      GBP    0.7126
#
# [11215 rows x 3 columns]

# %%
# checking null values
rate_df.isnull().sum()
# Out:
# Date        0
# Currency    0
# Exchange    0
# dtype: int64

# %%
#checking data types
rate_df.dtypes
# Out:
# Date         object
# Currency     object
# Exchange    float64
# dtype: object

# %%
#set Date column to date type rate_df
rate_df['Date']=pd.to_datetime(rate_df['Date'],format='%m/%d/%Y').dt.date
rate_df['Currency']=rate_df['Currency'].astype(str)
rate_df
# Out:
#              Date Currency  Exchange
# 0      2015-01-01      USD    1.0000
# 1      2015-01-01      CAD    1.1583
# 2      2015-01-01      AUD    1.2214
# 3      2015-01-01      EUR    0.8237
# 4      2015-01-01      GBP    0.6415
# ...           ...      ...       ...
# 11210  2021-02-20      USD    1.0000
# 11211  2021-02-20      CAD    1.2610
# 11212  2021-02-20      AUD    1.2723
# 11213  2021-02-20      EUR    0.8238
# 11214  2021-02-20      GBP    0.7126
#
# [11215 rows x 3 columns]

# %%
#checking datatypes post conversion
rate_df.dtypes
# Out:
# Date         object
# Currency     object
# Exchange    float64
# dtype: object

# %%
#To load the data to  table in SQL
rate_df.to_sql(name='exchange_rates', con=engine, if_exists='replace', index=False,chunksize=1000)
# Out:
# 11215

# %%
# To connect MySQL and validate the result from database DataSpark and table customers
with engine.connect() as connection:
    result = connection.execute(text("SELECT * FROM DataSpark.exchange_rates"))
    for row in result:
        print(row)
# Out:
# (datetime.date(2015, 1, 1), 'USD', 1.0)
# (datetime.date(2015, 1, 1), 'CAD', 1.1583)
# (datetime.date(2015, 1, 1), 'AUD', 1.2214)
# (datetime.date(2015, 1, 1), 'EUR', 0.8237)
# (datetime.date(2015, 1, 1), 'GBP', 0.6415)
# (datetime.date(2015, 1, 2), 'USD', 1.0)
# (datetime.date(2015, 1, 2), 'CAD', 1.1682)
# (datetime.date(2015, 1, 2), 'AUD', 1.2323)
# (datetime.date(2015, 1, 2), 'EUR', 0.8304)
# (datetime.date(2015, 1, 2), 'GBP', 0.6477)
# (datetime.date(2015, 1, 3), 'USD', 1.0)
# (datetime.date(2015, 1, 3), 'CAD', 1.1682)
# (datetime.date(2015, 1, 3), 'AUD', 1.2323)
# (datetime.date(2015, 1, 3), 'EUR', 0.8304)
# (datetime.date(2015, 1, 3), 'GBP', 0.6477)
# (datetime.date(2015, 1, 4), 'USD', 1.0)
# (datetime.date(2015, 1, 4), 'CAD', 1.1682)
# (datetime.date(2015, 1, 4), 'AUD', 1.2323)
# (datetime.date(2015, 1, 4), 'EUR', 0.8304)
# (datetime.date(2015, 1, 4), 'GBP', 0.6477)
# (datetime.date(2015, 1, 5), 'USD', 1.0)
# (datetime.date(2015, 1, 5), 'CAD', 1.1784)
# ...
